# %% [markdown]
# 1.任务一，将以下变量放到一张表中
# | 变量名称         | 变量定义                                       |
# |----------------|------------------------------------------------|
# | 子代年龄         | 子代年龄                                       |
# | 父代年龄         | 父母双方年龄的均值                             |
# | 性别             | 男=1, 女=0                                     |
# | 户口             | 农业户口=1, 非农业户口=0                       |
# | 婚姻状况         | 在婚=1, 未婚=0                                 |
# | 健康状况         | 1（不健康）至5（非常健康）                     |
# | 家庭存款状况     | 家庭存款和现金总值加1取对数                     |

# %% [markdown]
# 2. 计算CHFS2013,CHFS2015和CHFS2017的劳动力回流人数。
