# %% [markdown]
# 分组1：王亚柯,邵骄阳,杨建海.金融素养、家庭资产配置与财富积累[J].南开经济研究,2024,(06):167-184.DOI:10.14116/j.nkes.2024.06.010.
# <img src="figure/figure1.jpg" alt="示例图片" width="1200" height="350">

# %% [markdown]
# 计算：基于CHFS2015、CHFS2017和CHFS2019计算表1中除了金融素养以外的变量和家庭是否是农村地区的所有样本的描述性统计（均值，标准差，最小值和最大值）。

# %% [markdown]
# 分组2：谢尚,韦东明,唐琦.互联网使用对教育—工作匹配的影响——基于CFPS2016～2020的研究发现[J].中国人口科学,2024,38(04):36-51.

# %% [markdown]
# 计算：基于CFPS2016,CFPS2018和CFPS2020。计算教育失配度，互联网使用情况，受访者性别，年龄，受教育水平，有无配偶，户籍类型，家庭成员数，孩子数，现住房的产权，家庭年度纯收入和家庭是否是农村地区的所有样本的描述性统计（均值，标准差，最小值和最大值）。

# %% [markdown]
# 分组3：张中祥,胡雅慧.数字普惠金融如何影响家庭过度负债?——基于主客观双重视角的微观证据[J].经济学(季刊),2024,24(02):643-660.DOI:10.13821/j.cnki.ceq.2024.02.18.

# %% [markdown]
# <img src="figure/figure2.jpg" alt="示例图片" width="1200" height="350">

# %% [markdown]
# <img src="figure/figure4.jpg" alt="示例图片" width="1200" height="350">

# %% [markdown]
# 计算：基于CHFS2015，CHFS2017和CHFS2019计算除了数字普惠金融的其他变量，家庭是否是农村地区的描述性统计（均值，标准差，最小值和最大值）

# %% [markdown]
# 分组4：姚健,臧旭恒,周博文.社会网络与中国家庭金融脆弱性[J].金融研究,2024,(04):151-168.

# %% [markdown]
# 基于CHFS2017和CHFS2019计算家庭社会网络，户主年龄，年龄的平方/100，婚姻状况，健康状况、工作状况、受教育程度、养老保险参与、医疗保险参与、商业保险参与，家庭是否是农村地区的所有样本的描述性统计（均值，标准差，最小值和最大值）。

# %% [markdown]
# 分组5：王修华,熊鑫.数字金融发展对居民社会资本积累的影响——来自中国家庭追踪调查的证据[J].经济学动态,2024,(10):39-57.
#
# 基于CFPS2014,CFPS2016和CFPS2018计算个体特征变量:户口，年龄，性别，身体健康水平和受教育年限。二是人格特征变量：“不孤单”的重要性和“不被讨厌”的重要性。三是家庭特征变量：家庭人口规模，居住地城乡分类，家庭纯收入，家庭净资产和家庭是否是农村地区的描述性统计（均值，标准差，最小值和最大值）。

# %% [markdown]
# 分组6：雷晓燕,张春峰,李昕,等.人口变化、消费结构与低碳转型[J/OL].数量经济技术经济研究,1-25[2024-12-19].https://doi.org/10.13653/j.cnki.jqte.20241118.005.

# %% [markdown]
# 计算：基于CFPS2014,CFPS2016和CFPS2018：计算调整后家户人口规模，计算60岁及以上和60岁及以下食品消费，服装消费，居住消费，日常消费，医疗消费，交通通信消费，教育娱乐消费和总消费的平均值。

# %% [markdown]
# 分组7：骆文月,高瑜,寇海洁.移动支付、感知风险与中国家庭金融市场参与[J].南开经济研究,2024,(06):148-166.DOI:10.14116/j.nkes.2024.06.009.

# %% [markdown]
# 计算：基于CHFS2019计算移动支付，性别(男性赋值1，女性赋值2)、是否汉族、是否党员、文化程度、户口、婚姻状态、健康状况、投资倾向、年龄、年龄的平方/100，家庭总收入、家庭总资产，家庭是否是农村地区的描述性统计（均值，标准差，最小值和最大值）。
