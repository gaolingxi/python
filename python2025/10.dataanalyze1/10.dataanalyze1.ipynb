# %% [markdown]
# # 数据处理1-消费数据

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Department': ['HR', 'Finance', 'IT']
}

import pandas as pd

# 创建数据框
df = pd.DataFrame(data)

# 显示数据框
print(df)
# Out:
#       Name  Age Department
# 0    Alice   25         HR
# 1      Bob   30    Finance
# 2  Charlie   35         IT

# %%
! pip uninstall openpyxl
! pip install openpyxl
# Out:
# ^C
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: openpyxl in c:\users\gao_l\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\gao_l\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
# 读取Excel文件
df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")
#读取Excel文件
df_family = pd.read_excel("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020famecon_202306.xlsx")
# Out:
# C:\Users\gao_l\AppData\Local\Temp\ipykernel_31616\929306781.py:3: DtypeWarning: Columns (3,9,27,30,36,61,62,69,251,268,287,456,1097,1098,1099,1100,1101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")

# %%
print(df_family)
# Out:
#          fid20    fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0       100051   100051  100051  100051  110043  110043      北京市        45.0
# 1       100160   100160  100160  100160  120009  120009      天津市       189.0
# 2       100286   100286  100286  100286  130005  130005      河北省       239.0
# 3       100376   100376  100376  100376  130094  130094      河北省       235.0
# 4       100435   100435  100435  100435  130155  130155      河北省        52.0
# ...        ...      ...     ...     ...     ...     ...      ...         ...
# 11615  6694541  6694541  211229  211229  211229  211229   内蒙古自治区       592.0
# 11616  6704011  6704011  220306  220306  220306  220306      吉林省        59.0
# 11617  6759191  6759191  410650  410650  410650  410650      河南省       105.0
# 11618  6769401   620012  620012  620012  620012  620012      北京市       176.0
# 11619  6929111   450020  450020  450020  450020  450020      广东省       127.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 0      624942.0      城镇  ...    626000.0      0.760447        0.781139
# 1      800637.0      城镇  ...   1598700.0      1.136036        1.166948
# 2           NaN      缺失  ...      2500.0      1.752906        1.800603
# 3      418358.0      城镇  ...     10000.0      1.375133        1.412551
# 4      121200.0      乡村  ...    637000.0      0.871148        0.894852
# ...         ...     ...  ...         ...           ...             ...
# 11615       NaN      缺失  ...     75000.0      0.259222        0.161145
# 11616  123900.0      城镇  ...     59600.0      1.029976        1.058002
# 11617       NaN      城镇  ...    980000.0      0.692152        0.750392
# 11618  477349.0      城镇  ...      9000.0      0.155687        0.135495
# 11619       NaN      缺失  ...    290000.0      2.562173        2.631890
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 0              是        其它省市子总体            3   45          427784       NaN
# 1              是        其它省市子总体            3   79          136496       NaN
# 2              是        其它省市子总体            1   47          856047       NaN
# 3              是        其它省市子总体            3   47          856047       NaN
# 4              是        其它省市子总体            4   52          147691       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11615          否         辽宁省子总体            3  171          817084       NaN
# 11616          是        其它省市子总体            3   59          283491       NaN
# 11617          是         河南省子总体            3  119          964048       NaN
# 11618          否         甘肃省子总体            1  152          300018       NaN
# 11619          是        其它省市子总体            1    4          717217       NaN
#
#       releaseversion
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 11615            1.0
# 11616            1.0
# 11617            1.0
# 11618            1.0
# 11619            1.0
#
# [11620 rows x 327 columns]

# %%
print(df_person)
# Out:
#               pid  code    fid20    fid18    fid16    fid14 fid12 fid10  \
# 0       100051501   501   100051   100051   100051   100051   不适用   不适用
# 1       100051502   502   100051   100051   100051   100051   不适用   不适用
# 2       100160601   601   100160   100160      不适用      不适用   不适用   不适用
# 3       100376551   551   100376   100376   100376      不适用   不适用   不适用
# 4       100551551   551   100551   100551   100551      不适用   不适用   不适用
# ...           ...   ...      ...      ...      ...      ...   ...   ...
# 28525  2350241551   551   235024   235024   235024      不适用   不适用   不适用
# 28526  2489151501   501  2489151  2489151  2489151  2489151   不适用   不适用
# 28527  2489151502   502  2489151  2489151  2489151  2489151   不适用   不适用
# 28528  2844271552   552  2844271  2844271  2844271      不适用   不适用   不适用
# 28529  6694541651   651  6694541      不适用      不适用      不适用   不适用   不适用
#
#        fid_base age  ... qz204 qz207  qz5 pg02  cfps2020edu  cfps2020sch  \
# 0        110043  51  ...   不适用     5    5  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 1        110043  54  ...   不适用     5    1  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 2        120009  31  ...   不适用     7    3  NaN         大学本科         大学本科
# 3        130094  23  ...   不适用     6    2  NaN           初中           初中
# 4        130281  30  ...   不适用     5    3  NaN         大学本科         大学本科
# ...         ...  ..  ...   ...   ...  ...  ...          ...          ...
# 28525    621081  61  ...   不适用     4    4  NaN           初中           缺失
# 28526    410954  48  ...   不适用     5    4  NaN           小学           缺失
# 28527    410954  47  ...   不适用     5    5  NaN       文盲/半文盲       文盲/半文盲
# 28528    420385  47  ...   NaN   NaN  NaN    否  高中/中专/技校/职高           缺失
# 28529    211229  24  ...   不适用     4    2  NaN  高中/中专/技校/职高  高中/中专/技校/职高
#
#       cfps2020eduy cfps2020eduy_im  interviewerid20 releaseversion
# 0               12              12           427784            2.0
# 1               12              12           427784            2.0
# 2               16              16           136496            2.0
# 3                9               9           856047            2.0
# 4               16              16           856047            2.0
# ...            ...             ...              ...            ...
# 28525           缺失              缺失           888818            2.0
# 28526           缺失              缺失           823876            2.0
# 28527            0               0           823876            2.0
# 28528           缺失              缺失           584595            2.0
# 28529           12              12           817084            2.0
#
# [28530 rows x 1312 columns]

# %%
# 提取列
# 总消费支出
pce = df_family['pce']
print(pce)
# Out:
# 0         91260.0
# 1        300370.0
# 2         29800.0
# 3         52400.0
# 4         50250.0
#            ...
# 11615     93000.0
# 11616     15980.0
# 11617     51850.0
# 11618     42880.0
# 11619     42619.0
# Name: pce, Length: 11620, dtype: float64

# %%
pce = df_family['pce']
fid1820 = df_family[['fid18', 'fid20']]
print(fid1820)
# Out:
#          fid18    fid20
# 0       100051   100051
# 1       100160   100160
# 2       100286   100286
# 3       100376   100376
# 4       100435   100435
# ...        ...      ...
# 11615  6694541  6694541
# 11616  6704011  6704011
# 11617  6759191  6759191
# 11618   620012  6769401
# 11619   450020  6929111
#
# [11620 rows x 2 columns]

# %%
# 提取行(通过筛选数据)
# dataframe中的query函数
fid20 = df_family.query('fid20 == 100051')
print(fid20)
# Out:
#     fid20   fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0  100051  100051  100051  100051  110043  110043      北京市        45.0
#
#       cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  subsample  \
# 0  624942.0      城镇  ...    626000.0      0.760447        0.781139          是
#
#    subpopulation familysize20 psu interviewerid20 interrupt releaseversion
# 0        其它省市子总体            3  45          427784       NaN            1.0
#
# [1 rows x 327 columns]

# %%
df_family_1 = df_family.iloc[[0, 2]]
print(df_family_1)
df_family_1 = df_family.iloc[0:2]
print(df_family_1)
# Out:
#     fid20   fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0  100051  100051  100051  100051  110043  110043      北京市        45.0
# 2  100286  100286  100286  100286  130005  130005      河北省       239.0
#
#       cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  subsample  \
# 0  624942.0      城镇  ...    626000.0      0.760447        0.781139          是
# 2       NaN      缺失  ...      2500.0      1.752906        1.800603          是
#
#    subpopulation familysize20 psu interviewerid20 interrupt releaseversion
# 0        其它省市子总体            3  45          427784       NaN            1.0
# 2        其它省市子总体            1  47          856047       NaN            1.0
#
# [2 rows x 327 columns]
#     fid20   fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0  100051  100051  100051  100051  110043  110043      北京市        45.0
# 1  100160  100160  100160  100160  120009  120009      天津市       189.0
#
#       cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  subsample  \
# 0  624942.0      城镇  ...    626000.0      0.760447        0.781139          是
# 1  800637.0      城镇  ...   1598700.0      1.136036        1.166948          是
#
#    subpopulation familysize20 psu interviewerid20 interrupt releaseversion
# 0        其它省市子总体            3  45          427784       NaN            1.0
# 1        其它省市子总体            3  79          136496       NaN            1.0
#
# [2 rows x 327 columns]

# %% [markdown]
# 在pandas中，当你使用astype(str)将DataFrame的列转换为字符串类型时，这些列的数据类型会显示为object。这是因为pandas中的object数据类型用于表示存储在列中的数据是Python对象，而字符串在Python中是对象的一种。

# %%
print(df_family)
# Out:
#          fid20    fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0       100051   100051  100051  100051  110043  110043      北京市        45.0
# 1       100160   100160  100160  100160  120009  120009      天津市       189.0
# 2       100286   100286  100286  100286  130005  130005      河北省       239.0
# 3       100376   100376  100376  100376  130094  130094      河北省       235.0
# 4       100435   100435  100435  100435  130155  130155      河北省        52.0
# ...        ...      ...     ...     ...     ...     ...      ...         ...
# 11615  6694541  6694541  211229  211229  211229  211229   内蒙古自治区       592.0
# 11616  6704011  6704011  220306  220306  220306  220306      吉林省        59.0
# 11617  6759191  6759191  410650  410650  410650  410650      河南省       105.0
# 11618  6769401   620012  620012  620012  620012  620012      北京市       176.0
# 11619  6929111   450020  450020  450020  450020  450020      广东省       127.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 0      624942.0      城镇  ...    626000.0      0.760447        0.781139
# 1      800637.0      城镇  ...   1598700.0      1.136036        1.166948
# 2           NaN      缺失  ...      2500.0      1.752906        1.800603
# 3      418358.0      城镇  ...     10000.0      1.375133        1.412551
# 4      121200.0      乡村  ...    637000.0      0.871148        0.894852
# ...         ...     ...  ...         ...           ...             ...
# 11615       NaN      缺失  ...     75000.0      0.259222        0.161145
# 11616  123900.0      城镇  ...     59600.0      1.029976        1.058002
# 11617       NaN      城镇  ...    980000.0      0.692152        0.750392
# 11618  477349.0      城镇  ...      9000.0      0.155687        0.135495
# 11619       NaN      缺失  ...    290000.0      2.562173        2.631890
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 0              是        其它省市子总体            3   45          427784       NaN
# 1              是        其它省市子总体            3   79          136496       NaN
# 2              是        其它省市子总体            1   47          856047       NaN
# 3              是        其它省市子总体            3   47          856047       NaN
# 4              是        其它省市子总体            4   52          147691       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11615          否         辽宁省子总体            3  171          817084       NaN
# 11616          是        其它省市子总体            3   59          283491       NaN
# 11617          是         河南省子总体            3  119          964048       NaN
# 11618          否         甘肃省子总体            1  152          300018       NaN
# 11619          是        其它省市子总体            1    4          717217       NaN
#
#       releaseversion
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 11615            1.0
# 11616            1.0
# 11617            1.0
# 11618            1.0
# 11619            1.0
#
# [11620 rows x 327 columns]

# %%
# 数据类型的转换
# 将fid20转为字符串
df_family[['fid20', 'fid18']] = df_family[['fid20', 'fid18']].astype(str)
df_family = df_family.astype({'fid20': str, 'fid18': str})
print(df_family.dtypes)
print(df_family)
# Out:
# fid20               object
# fid18               object
# fid16                int64
# fid14                int64
# fid12                int64
#                     ...
# familysize20         int64
# psu                  int64
# interviewerid20      int64
# interrupt          float64
# releaseversion     float64
# Length: 327, dtype: object
#          fid20    fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0       100051   100051  100051  100051  110043  110043      北京市        45.0
# 1       100160   100160  100160  100160  120009  120009      天津市       189.0
# 2       100286   100286  100286  100286  130005  130005      河北省       239.0
# 3       100376   100376  100376  100376  130094  130094      河北省       235.0
# 4       100435   100435  100435  100435  130155  130155      河北省        52.0
# ...        ...      ...     ...     ...     ...     ...      ...         ...
# 11615  6694541  6694541  211229  211229  211229  211229   内蒙古自治区       592.0
# 11616  6704011  6704011  220306  220306  220306  220306      吉林省        59.0
# 11617  6759191  6759191  410650  410650  410650  410650      河南省       105.0
# 11618  6769401   620012  620012  620012  620012  620012      北京市       176.0
# 11619  6929111   450020  450020  450020  450020  450020      广东省       127.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 0      624942.0      城镇  ...    626000.0      0.760447        0.781139
# 1      800637.0      城镇  ...   1598700.0      1.136036        1.166948
# 2           NaN      缺失  ...      2500.0      1.752906        1.800603
# 3      418358.0      城镇  ...     10000.0      1.375133        1.412551
# 4      121200.0      乡村  ...    637000.0      0.871148        0.894852
# ...         ...     ...  ...         ...           ...             ...
# 11615       NaN      缺失  ...     75000.0      0.259222        0.161145
# 11616  123900.0      城镇  ...     59600.0      1.029976        1.058002
# 11617       NaN      城镇  ...    980000.0      0.692152        0.750392
# 11618  477349.0      城镇  ...      9000.0      0.155687        0.135495
# 11619       NaN      缺失  ...    290000.0      2.562173        2.631890
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 0              是        其它省市子总体            3   45          427784       NaN
# 1              是        其它省市子总体            3   79          136496       NaN
# 2              是        其它省市子总体            1   47          856047       NaN
# 3              是        其它省市子总体            3   47          856047       NaN
# 4              是        其它省市子总体            4   52          147691       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11615          否         辽宁省子总体            3  171          817084       NaN
# 11616          是        其它省市子总体            3   59          283491       NaN
# 11617          是         河南省子总体            3  119          964048       NaN
# 11618          否         甘肃省子总体            1  152          300018       NaN
# 11619          是        其它省市子总体            1    4          717217       NaN
#
#       releaseversion
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 11615            1.0
# 11616            1.0
# 11617            1.0
# 11618            1.0
# 11619            1.0
#
# [11620 rows x 327 columns]

# %%
# 数据删除重复值
df_province = df_family['provcd20'].drop_duplicates()
print(df_province)
# Out:
# 0            北京市
# 1            天津市
# 2            河北省
# 5            湖南省
# 10           山东省
# 18           山西省
# 22           河南省
# 23           辽宁省
# 32           上海市
# 33           浙江省
# 35          黑龙江省
# 42           江苏省
# 44           安徽省
# 45           福建省
# 48           江西省
# 52           广东省
# 58           甘肃省
# 68      新疆维吾尔自治区
# 75           贵州省
# 148      广西壮族自治区
# 151          四川省
# 161          云南省
# 165          陕西省
# 250          吉林省
# 276          湖北省
# 666       内蒙古自治区
# 1362         重庆市
# 1579     宁夏回族自治区
# 1751       西藏自治区
# 3243         青海省
# 6459         海南省
# Name: provcd20, dtype: object

# %% [markdown]
# ## 描述性统计

# %% [markdown]
# ## 直方图和密度图
# Seaborn允许你将直方图和密度图结合在一起，这样可以更直观地看到数据的分布情况和密度估计。

# %%
! pip install seaborn matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: seaborn in c:\users\gao_l\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\gao_l\miniconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\gao_l\miniconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\gao_l\miniconda3\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (4.43.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gao_l\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gao_l\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gao_l\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gao_l\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gao_l\miniconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 使用seaborn绘制直方图和密度图
sns.histplot(df_family['expense'], kde= True, stat="density", linewidth=0)

# 设置图形的标题和标签
plt.title('Histogram and Density Plot of Expense')
# plt.xlabel('Expense')
# plt.ylabel('Density')
# Out:
# Text(0.5, 1.0, 'Histogram and Density Plot of Expense')

# %% [markdown]
# 分位数是统计学中用来描述数据分布的一个概念，它表示将数据集分成若干等份的数值。分位数可以帮助我们了解数据的分布情况，尤其是在数据量较大或者数据分布不均匀时。以下是一些常见的分位数及其定义：
#
# * 最小值（Min）：数据集中最小的数值，可以看作是0%的分位数。
#
# * 第一四分位数（Q1，25%分位数）：将数据集从小到大排序后，位于25%位置的数值。这意味着25%的数据项小于或等于这个值。
#
# * 中位数（Q2，50%分位数）：数据集的中间值，即50%的分位数。如果数据集的元素个数是奇数，中位数就是中间的那个数；如果是偶数，则是中间两个数的平均值。
#
# * 第三四分位数（Q3，75%分位数）：位于75%位置的数值，表示75%的数据项小于或等于这个值。
#
# * 最大值（Max）：数据集中最大的数值，可以看作是100%的分位数。

# %% [markdown]
# ```df_family['expense']```的缺失值

# %%
import numpy as np
data = np.array([1, 2, 2, 3, 4, 5, 5, 5, 6, 7])
Q1 = np.percentile(data, 25)  # 第一四分位数
Q2 = np.percentile(data, 50)  # 中位数
Q3 = np.percentile(data, 75)  # 第三四分位数

print(f"第25百分位数（Q1）: {Q1}")
print(f"中位数（Q2）: {Q2}")
print(f"第75百分位数（Q3）: {Q3}")
# Out:
# 第25百分位数（Q1）: 2.25
# 中位数（Q2）: 4.5
# 第75百分位数（Q3）: 5.0

# %%
import pandas as pd

# 创建数据字典
data = {
    'expense': [200, 150, np.nan, 250, 180],
    'income': [250, 200, 350, 300, 220]
}

# 创建DataFrame
data = pd.DataFrame(data)

# 显示DataFrame
print(data)
data = data.dropna(subset=['expense'])
np.percentile(data , 50)
# Out:
#    expense  income
# 0    200.0     250
# 1    150.0     200
# 2      NaN     350
# 3    250.0     300
# 4    180.0     220
# 210.0

# %%
df_family = df_family.dropna(subset=['expense'])

# 计算第1百分位数和第90百分位数
Q1 = np.percentile(df_family["expense"], 1)
print(Q1)
Q99 = np.percentile(df_family["expense"], 90)
print(Q99)
# 使用布尔索引过滤掉超出[Q1, Q99]范围的值
df_family = df_family.dropna(subset=['expense'])
df_family_99 = df_family[(df_family["expense"] >= Q1) & (df_family["expense"] <= Q99)]
# Out:
# 3500.0
# 172618.00000000006

# %%
# 使用seaborn绘制直方图和密度图
sns.histplot(df_family_99['expense'], kde=True, stat="density", linewidth=0)

# 设置图形的标题和标签
plt.title('Histogram and Density Plot of Expense')
plt.xlabel('Expense')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
from scipy import stats

# 使用scipy计算描述性统计信息
desc_stats = stats.describe(df_family_99['expense'])

# 打印描述性统计信息
print(f"Count: {desc_stats.nobs}")
print(f"Mean: {desc_stats.mean:.3f}")
print(f"Variance: {desc_stats.variance:.3f}")
print(f"Min: {desc_stats.minmax[0]:.3f}")
print(f"Max: {desc_stats.minmax[1]:.3f}")
# Out:
# Count: 10198
# Mean: 60170.845
# Variance: 1647746419.223
# Min: 3500.000
# Max: 172600.000

# %%
import seaborn as sns
# 使用seaborn绘制直方图和密度图
sns.histplot(df_family_99['expense'], kde=True, stat="density", linewidth=0)

# 设置图形的标题和标签
plt.title('Histogram and Density Plot of Expense')
plt.xlabel('Expense')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
print(df_family_99)
# Out:
#          fid20    fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0       100051   100051  100051  100051  110043  110043      北京市        45.0
# 2       100286   100286  100286  100286  130005  130005      河北省       239.0
# 3       100376   100376  100376  100376  130094  130094      河北省       235.0
# 4       100435   100435  100435  100435  130155  130155      河北省        52.0
# 5       100453   100453  100453  100453  100453  430111      湖南省        29.0
# ...        ...      ...     ...     ...     ...     ...      ...         ...
# 11615  6694541  6694541  211229  211229  211229  211229   内蒙古自治区       592.0
# 11616  6704011  6704011  220306  220306  220306  220306      吉林省        59.0
# 11617  6759191  6759191  410650  410650  410650  410650      河南省       105.0
# 11618  6769401   620012  620012  620012  620012  620012      北京市       176.0
# 11619  6929111   450020  450020  450020  450020  450020      广东省       127.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 0      624942.0      城镇  ...    626000.0      0.760447        0.781139
# 2           NaN      缺失  ...      2500.0      1.752906        1.800603
# 3      418358.0      城镇  ...     10000.0      1.375133        1.412551
# 4      121200.0      乡村  ...    637000.0      0.871148        0.894852
# 5      533420.0      城镇  ...   3050000.0      2.114091        2.171616
# ...         ...     ...  ...         ...           ...             ...
# 11615       NaN      缺失  ...     75000.0      0.259222        0.161145
# 11616  123900.0      城镇  ...     59600.0      1.029976        1.058002
# 11617       NaN      城镇  ...    980000.0      0.692152        0.750392
# 11618  477349.0      城镇  ...      9000.0      0.155687        0.135495
# 11619       NaN      缺失  ...    290000.0      2.562173        2.631890
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 0              是        其它省市子总体            3   45          427784       NaN
# 2              是        其它省市子总体            1   47          856047       NaN
# 3              是        其它省市子总体            3   47          856047       NaN
# 4              是        其它省市子总体            4   52          147691       NaN
# 5              是        其它省市子总体            6   29          845680       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11615          否         辽宁省子总体            3  171          817084       NaN
# 11616          是        其它省市子总体            3   59          283491       NaN
# 11617          是         河南省子总体            3  119          964048       NaN
# 11618          否         甘肃省子总体            1  152          300018       NaN
# 11619          是        其它省市子总体            1    4          717217       NaN
#
#       releaseversion
# 0                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# 5                1.0
# ...              ...
# 11615            1.0
# 11616            1.0
# 11617            1.0
# 11618            1.0
# 11619            1.0
#
# [10198 rows x 327 columns]

# %% [markdown]
# ### 计算消费分类
# #### 国家统计局的消费分类
# https://data.stats.gov.cn/easyquery.htm?cn=E0101

# %% [markdown]
# #### 消费分类
# | 一级消费类型   | 二级消费类型 | cfps2020 |
# |----------------|--------------|----------|
# | 生存型消费     | 食品消费     | food     |
# |                | 居住消费     | house    |
# |                | 衣着消费     | dress    |
# | 发展享受型消费 | 文教娱乐     | eec      |
# |                | 医疗保健     | med      |
# |                | 交通通信     | trco     |
# |                | 家庭设备及用品 | daily    |
# |                | 其他用品及服务 | other    |
# | 耐用品消费     | 住房维修费   | FP506    |
# |                | 汽车购置     | FP507N   |
# |                | 交通通信设备 | FP508    |
# |                | 家具耐用品   | FP509    |
# | 总消费         |              | pce      |

# %% [markdown]
# ## 清理数据，数据中可能有缺失，不适用，不知道，数据类型不对

# %%
missing_food = df_family_99[df_family_99['food'].isnull()]
print(missing_food)
# Out:
#         fid20   fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 259    123392  123392  123392  320219  320219  320219      江苏省        11.0
# 276    126209  126209  126209  411168  411168  411168      湖北省      1750.0
# 389    130149  130149  130149  130149  130149  130149      河北省        52.0
# 476    130351  130351  130351  130351  130351  130351      河北省        49.0
# 502    130426  130426  130426  130426  130426  130426      河北省        49.0
# ...       ...     ...     ...     ...     ...     ...      ...         ...
# 11037  638824  638824  370076  370076  370076  370076      山东省        67.0
# 11135  652721  440273  440273  440273  440273  440273  广西壮族自治区       356.0
# 11287  673163  441584  441584  441584  441584  441584      广东省      2006.0
# 11477  729951  729951  729951  729951  729951  430311      湖南省        31.0
# 11482  746302  746302  746302  746302  746302  370755      山东省      8467.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 259    795858.0      城镇  ...    310000.0      0.634230        0.651487
# 276         NaN      缺失  ...     31000.0      0.725947        0.787031
# 389    121200.0      乡村  ...    400000.0      1.114348        1.144669
# 476    119800.0      乡村  ...     63300.0      1.909646        1.961608
# 502    120000.0      乡村  ...     96270.0      0.923472        0.948599
# ...         ...     ...  ...         ...           ...             ...
# 11037  127100.0      乡村  ...     84500.0      1.320729        1.356666
# 11135  103252.0      乡村  ...         NaN      0.471274        0.420303
# 11287       NaN      缺失  ...     20000.0      0.529596        0.472318
# 11477  567366.0      乡村  ...         NaN      0.264924        0.272133
# 11482  886917.0      城镇  ...    502225.0      1.140171        1.171195
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 259            是        其它省市子总体            4   11          372691       NaN
# 276            是         河南省子总体            1  127          384410       NaN
# 389            是        其它省市子总体            5   52          147691       NaN
# 476            是        其它省市子总体            4   49          164270       NaN
# 502            是        其它省市子总体            4   49          164270       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11037          是        其它省市子总体            2   67          480296       NaN
# 11135          是         广东省子总体            4  136          622526       NaN
# 11287          是         广东省子总体            1  142          630954       NaN
# 11477          是        其它省市子总体            7   31          591878       NaN
# 11482          是        其它省市子总体            2   62          482402       NaN
#
#       releaseversion
# 259              1.0
# 276              1.0
# 389              1.0
# 476              1.0
# 502              1.0
# ...              ...
# 11037            1.0
# 11135            1.0
# 11287            1.0
# 11477            1.0
# 11482            1.0
#
# [104 rows x 327 columns]

# %%
missingvalue1 = df_family_99[df_family_99['fp506'] == '不知道']
print(missingvalue1)
# Out:
#         fid20   fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 958    140102  140102  140102  140102  140102  140102      山西省        69.0
# 1428   155005  155005  155005  155005  510588  510588      四川省      2289.0
# 2227   211031  211031  211031  211031  211031  211031      辽宁省       150.0
# 3635   310288  310288  310288  310288  310288  310288      上海市        83.0
# 4636   350078  350078  350078  350078  350078  350078      福建省        27.0
# 7377   441924  441924  441924  441924  441924  441924      广东省       123.0
# 7394   441945  441945  441945  441945  441945  441945      广东省       123.0
# 8503   520518  520518  520518  520518  520518  520518      贵州省        26.0
# 8504   520521  520521  520521  520521  520521  520521      贵州省        26.0
# 10503  621147  621147  410311  410311  410311  410311      河南省       101.0
# 11477  729951  729951  729951  729951  729951  430311      湖南省        31.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 958    128000.0      乡村  ...         NaN      1.304888        1.340394
# 1428        NaN      缺失  ...         NaN      1.086155        1.115710
# 2227   227200.0      乡村  ...    288437.5      0.229228        0.142499
# 3635   168739.0      城镇  ...   2344000.0      0.154555        0.090685
# 4636   110700.0      城镇  ...    601250.0      0.694128        0.713015
# 7377        NaN      乡村  ...    798250.0      0.335483        0.299199
# 7394        NaN      乡村  ...         NaN      0.718908        0.641154
# 8503   795720.0      城镇  ...    112962.5      1.557609        1.599992
# 8504   795584.0      乡村  ...    100562.5      1.860976        1.911613
# 10503  207400.0      乡村  ...    136700.0      0.390667        0.423539
# 11477  567366.0      乡村  ...         NaN      0.264924        0.272133
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 958            是        其它省市子总体            4   69          201697       NaN
# 1428           是        其它省市子总体            6   42          744379       NaN
# 2227           否         辽宁省子总体            2  164          237816       NaN
# 3635           否         上海市子总体            2   84          356313       NaN
# 4636           是        其它省市子总体            6   27          451977       NaN
# 7377           否         广东省子总体           11  137          662044       NaN
# 7394           否         广东省子总体            5  137          662044       NaN
# 8503           是        其它省市子总体            4   26          787081       NaN
# 8504           是        其它省市子总体            5   26          798136       NaN
# 10503          否         河南省子总体            4  115          573481       NaN
# 11477          是        其它省市子总体            7   31          591878       NaN
#
#       releaseversion
# 958              1.0
# 1428             1.0
# 2227             1.0
# 3635             1.0
# 4636             1.0
# 7377             1.0
# 7394             1.0
# 8503             1.0
# 8504             1.0
# 10503            1.0
# 11477            1.0
#
# [11 rows x 327 columns]

# %%
columns_to_check = ['food', 'house', 'dress', 'eec', 'med', 'trco', 'daily', 'other', 'fp506', 'fp507n', 'fp508', 'fp509', 'expense']

# 遍历指定的列
for column in columns_to_check:
    # 填充缺失值为0
    df_family_99[column] = df_family_99[column].fillna(0)

    # 将"不适用"替换为0
    df_family_99[column] = df_family_99[column].replace('不适用','0')

    # 删除掉变量中的不知道
    df_family_99 = df_family_99[df_family_99[column] != '不知道']

    # 将字符串转为整型
    df_family_99[column] = df_family_99[column].apply(lambda x: int(x)).astype('int64')
# Out:
# C:\Users\gao_l\AppData\Local\Temp\ipykernel_27780\2916868631.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_family_99[column] = df_family_99[column].fillna(0)
# C:\Users\gao_l\AppData\Local\Temp\ipykernel_27780\2916868631.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_family_99[column] = df_family_99[column].replace('不适用','0')

# %%
df_family_99['living_consump'] = df_family_99[['food', 'house', 'dress']].sum(axis = 1) # DataFrame是一个二维对象，有两个轴, axis=0表示沿着行（垂直向下）操作，而axis=1表示沿着列（水平向右）操作。
df_family_99['deen_consump'] = df_family_99[['eec', 'med', 'trco', 'daily', 'other']].sum(axis = 1) 
df_family_99['durable'] = df_family_99[['fp506', 'fp507n', 'fp508', 'fp509']].sum(axis = 1)

# %%
df_family_99['consump_durable'] = df_family_99['expense'] - df_family_99['durable']
df_family_99['living_consump_durable'] = df_family_99['living_consump'] - df_family_99['fp506']
df_family_99['deen_consump_durable'] = df_family_99['deen_consump'] - df_family_99[['fp507n', 'fp508', 'fp509']].sum(axis = 1)
df_family_99['year'] = 2020

# %% [markdown]
# ## 保存计算结果到表格中

# %%
colummns_to_save1 = ['living_consump', 'deen_consump', 'durable', 'consump_durable', 'living_consump_durable', 'deen_consump_durable', 'year']
columns_to_save2 = []
for i in range(10, 21, 2):  # 从10开始，到15结束，步长为2
    columns_to_save2.append(f'fid{i}')
colummns_to_save = colummns_to_save1 + columns_to_save2

consump2020 = df_family_99[colummns_to_save]
consump2020.to_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\result\\consump2020.csv", index=False)

# %% [markdown]
# ## 创建面板数据
#
# 面板数据（Panel Data），也称为纵向数据（Longitudinal Data）或追踪数据（Track Data），是一种数据类型，它包含了多个时间序列的数据，这些数据是针对同一组个体（如个人、公司、国家等）在不同时间点收集的。

# %% [markdown]
# | 国家 | 年份 | GDP（亿美元） |
# |------|------|-------------|
# | A国  | 2010 | 1500        |
# | A国  | 2011 | 1600        |
# | A国  | 2012 | 1700        |
# | B国  | 2010 | 2000        |
# | B国  | 2011 | 2100        |
# | B国  | 2012 | 2200        |
# | C国  | 2010 | 1000        |
# | C国  | 2011 | 1100        |
# | C国  | 2012 | 1200        |

# %% [markdown]
# ## 描述性统计-（样本量，平均数，方差，最小值，最大值）

# %%
from scipy import stats

# 使用scipy计算描述性统计信息
desc_stats = stats.describe(df_family_99['expense'])

# 打印描述性统计信息
print(f"Count: {desc_stats.nobs}")
print(f"Mean: {desc_stats.mean:.3f}")
print(f"Variance: {desc_stats.variance:.3f}")
print(f"Min: {desc_stats.minmax[0]:.3f}")
print(f"Max: {desc_stats.minmax[1]:.3f}")
# Out:
# Count: 9905
# Mean: 60608.317
# Variance: 1658986593.763
# Min: 3500.000
# Max: 172600.000

# %%
df_family_2022 = pd.read_stata("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2022\\CFPS2022Stata\\cfps2022famecon_202410.dta")
df_relation_2022 = pd.read_stata("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2022\\CFPS2022Stata\\cfps2022person_202410.dta")

import pandas as pd
import numpy as np

df_family_2022 = df_family_2022.dropna(subset=['expense'])
df_family_2022['expense'] = df_family_2022['expense'].astype(int)
# 计算第1百分位数和第90百分位数
Q1 = np.percentile(df_family_2022["expense"], 1)
print(Q1)
Q99 = np.percentile(df_family_2022["expense"], 90)
print(Q99)
# 使用布尔索引过滤掉超出[Q1, Q99]范围的值

df_family_2022 = df_family_2022[(df_family_2022["expense"] >= Q1) & (df_family_2022["expense"] <= Q99)]

columns_to_check = ['food', 'house', 'dress', 'eec', 'med', 'trco', 'daily', 'other', 'fp506', 'fp507n', 'fp508', 'fp509']

# 遍历指定的列
for column in columns_to_check:
    # 填充缺失值为0
    df_family_2022[column] = df_family_2022[column].fillna(0)

    # 将"不适用"替换为0
    df_family_2022[column] = df_family_2022[column].replace('不适用','0')

    # 删除掉变量中的不知道
    df_family_2022 = df_family_2022[df_family_2022[column] != '不知道']

    # 将字符串转为整型
    df_family_2022[column] = pd.to_numeric(df_family_2022[column], errors='coerce').astype('Int64')

df_family_2022['living_consump'] = df_family_2022[['food', 'house', 'dress']].sum(axis = 1) # DataFrame是一个二维对象，有两个轴, axis=0表示沿着行（垂直向下）操作，而axis=1表示沿着列（水平向右）操作。
df_family_2022['deen_consump'] = df_family_2022[['eec', 'med', 'trco', 'daily', 'other']].sum(axis = 1) 
df_family_2022['durable'] = df_family_2022[['fp506', 'fp507n', 'fp508', 'fp509']].sum(axis = 1) 
df_family_2022['consump_durable'] = df_family_2022['expense'] - df_family_2022['durable']
df_family_2022['living_consump_durable'] = df_family_2022['living_consump'] - df_family_2022['fp506']
df_family_2022['deen_consump_durable'] = df_family_2022['deen_consump'] - df_family_2022[['fp507n', 'fp508', 'fp509']].sum(axis = 1)
df_family_2022['year'] = 2022

colummns_to_save1 = ['living_consump', 'deen_consump', 'durable', 'consump_durable', 'living_consump_durable', 'deen_consump_durable', 'year']
columns_to_save2 = []
for i in range(10, 23, 2):  # 从10开始，到22结束，步长为2
    columns_to_save2.append(f'fid{i}')
colummns_to_save = colummns_to_save1 + columns_to_save2

consump2022 = df_family_2022[colummns_to_save]
consump2022.to_csv("C:\\Users\\gao_l\Desktop\\python\\10.dataanalyze1\\result\\consump2022.csv", index=False)
# Out:
# 3838.44
# 190112.00000000006

# %% [markdown]
# ### 数据的合并与转换
# #### 数据合并
# 合并数据有两种方式，一是纵向添加观察值；二是横向匹配变量。

# %%
import pandas as pd

# 创建第一个DataFrame
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# 创建第二个DataFrame
df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
})

# 使用concat函数将df2添加到df1的末尾
df_combined = pd.concat([df1, df2], ignore_index=True)

# 打印合并后的DataFrame
print(df_combined)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
# 纵向添加观察值

df_2022_combined = pd.concat([consump2020, consump2022], ignore_index=True)
print(df_2022_combined)
# Out:
#        living_consump  deen_consump  durable  consump_durable  \
# 0               59160         32100    15000           121760
# 1               18400         11400      500            32300
# 2               38800         13600     2000            55400
# 3               36450         13800     4200            68050
# 4               13500         36900     6500            51400
# ...               ...           ...      ...              ...
# 19085           17000         23000     4000            43000
# 19086           22760          5540      100            45200
# 19087           39000          5312        0            44412
# 19088           26960         41770    20100            52630
# 19089           59240         25400    10000            77640
#
#        living_consump_durable  deen_consump_durable  year     fid10     fid12  \
# 0                       59160                 17100  2020  110043.0  110043.0
# 1                       18400                 10900  2020  130005.0  130005.0
# 2                       38800                 11600  2020  130094.0  130094.0
# 3                       36250                  9800  2020  130155.0  130155.0
# 4                       13000                 30900  2020  130281.0  130281.0
# ...                       ...                   ...   ...       ...       ...
# 19085                   17000                 19000  2022  340346.0  340346.0
# 19086                   22760                  5440  2022  211229.0  211229.0
# 19087                   39000                  5312  2022  220306.0  220306.0
# 19088                   26960                 21670  2022  410650.0  410650.0
# 19089                   59240                 15400  2022  620012.0  620012.0
#
#           fid14     fid16      fid18      fid20      fid22
# 0      100051.0  100051.0   100051.0   100051.0        NaN
# 1      100286.0  100286.0   100286.0   100286.0        NaN
# 2      100376.0  100376.0   100376.0   100376.0        NaN
# 3      100435.0  100435.0   100435.0   100435.0        NaN
# 4      100551.0  100551.0   100551.0   100551.0        NaN
# ...         ...       ...        ...        ...        ...
# 19085  340346.0  284365.0   284365.0  6662521.0  6662521.0
# 19086  211229.0  211229.0  6694541.0  6694541.0  6694541.0
# 19087  220306.0  220306.0  6704011.0  6704011.0  6704011.0
# 19088  410650.0  410650.0  6759191.0  6759191.0  6759191.0
# 19089  620012.0  620012.0   620012.0  6769401.0  6769401.0
#
# [19090 rows x 14 columns]

# %%
# 处理平衡面板
# 检查一下fid2022和fid2020是不是相等
# non_equal = df_2022_combined[df_2022_combined['fid20'] != df_2022_combined['fid22']]
# print(non_equal)

filtered_df = df_2022_combined.groupby('fid20').filter(lambda x: len(x) == 2)
print(filtered_df)
# Out:
#        living_consump  deen_consump  durable  consump_durable  \
# 0               59160         32100    15000           121760
# 4               13500         36900     6500            51400
# 5                9120         13620        0            38740
# 8              147340         19800   126000            43140
# 9               46060          4000    25000            25660
# ...               ...           ...      ...              ...
# 19085           17000         23000     4000            43000
# 19086           22760          5540      100            45200
# 19087           39000          5312        0            44412
# 19088           26960         41770    20100            52630
# 19089           59240         25400    10000            77640
#
#        living_consump_durable  deen_consump_durable  year     fid10     fid12  \
# 0                       59160                 17100  2020  110043.0  110043.0
# 4                       13000                 30900  2020  130281.0  130281.0
# 5                        9120                 13620  2020  130492.0  130492.0
# 8                       27340                 13800  2020  130533.0  130533.0
# 9                       21060                  4000  2020  130517.0  130517.0
# ...                       ...                   ...   ...       ...       ...
# 19085                   17000                 19000  2022  340346.0  340346.0
# 19086                   22760                  5440  2022  211229.0  211229.0
# 19087                   39000                  5312  2022  220306.0  220306.0
# 19088                   26960                 21670  2022  410650.0  410650.0
# 19089                   59240                 15400  2022  620012.0  620012.0
#
#           fid14     fid16      fid18      fid20      fid22
# 0      100051.0  100051.0   100051.0   100051.0        NaN
# 4      100551.0  100551.0   100551.0   100551.0        NaN
# 5      100724.0  100724.0   100724.0   100724.0        NaN
# 8      100765.0  100765.0   100765.0   100765.0        NaN
# 9      130517.0  100782.0   100782.0   100782.0        NaN
# ...         ...       ...        ...        ...        ...
# 19085  340346.0  284365.0   284365.0  6662521.0  6662521.0
# 19086  211229.0  211229.0  6694541.0  6694541.0  6694541.0
# 19087  220306.0  220306.0  6704011.0  6704011.0  6704011.0
# 19088  410650.0  410650.0  6759191.0  6759191.0  6759191.0
# 19089  620012.0  620012.0   620012.0  6769401.0  6769401.0
#
# [12568 rows x 14 columns]

# %% [markdown]
# ## 横向匹配变量

# %%
# 读取Excel文件
df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")
print(df_person)
# Out:
# C:\Users\gao_l\AppData\Local\Temp\ipykernel_27780\605242314.py:2: DtypeWarning: Columns (3,9,27,30,36,61,62,69,251,268,287,456,1097,1098,1099,1100,1101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")
#               pid  code    fid20    fid18    fid16    fid14 fid12 fid10  \
# 0       100051501   501   100051   100051   100051   100051   不适用   不适用
# 1       100051502   502   100051   100051   100051   100051   不适用   不适用
# 2       100160601   601   100160   100160      不适用      不适用   不适用   不适用
# 3       100376551   551   100376   100376   100376      不适用   不适用   不适用
# 4       100551551   551   100551   100551   100551      不适用   不适用   不适用
# ...           ...   ...      ...      ...      ...      ...   ...   ...
# 28525  2350241551   551   235024   235024   235024      不适用   不适用   不适用
# 28526  2489151501   501  2489151  2489151  2489151  2489151   不适用   不适用
# 28527  2489151502   502  2489151  2489151  2489151  2489151   不适用   不适用
# 28528  2844271552   552  2844271  2844271  2844271      不适用   不适用   不适用
# 28529  6694541651   651  6694541      不适用      不适用      不适用   不适用   不适用
#
#        fid_base age  ... qz204 qz207  qz5 pg02  cfps2020edu  cfps2020sch  \
# 0        110043  51  ...   不适用     5    5  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 1        110043  54  ...   不适用     5    1  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 2        120009  31  ...   不适用     7    3  NaN         大学本科         大学本科
# 3        130094  23  ...   不适用     6    2  NaN           初中           初中
# 4        130281  30  ...   不适用     5    3  NaN         大学本科         大学本科
# ...         ...  ..  ...   ...   ...  ...  ...          ...          ...
# 28525    621081  61  ...   不适用     4    4  NaN           初中           缺失
# 28526    410954  48  ...   不适用     5    4  NaN           小学           缺失
# 28527    410954  47  ...   不适用     5    5  NaN       文盲/半文盲       文盲/半文盲
# 28528    420385  47  ...   NaN   NaN  NaN    否  高中/中专/技校/职高           缺失
# 28529    211229  24  ...   不适用     4    2  NaN  高中/中专/技校/职高  高中/中专/技校/职高
#
#       cfps2020eduy cfps2020eduy_im  interviewerid20 releaseversion
# 0               12              12           427784            2.0
# 1               12              12           427784            2.0
# 2               16              16           136496            2.0
# 3                9               9           856047            2.0
# 4               16              16           856047            2.0
# ...            ...             ...              ...            ...
# 28525           缺失              缺失           888818            2.0
# 28526           缺失              缺失           823876            2.0
# 28527            0               0           823876            2.0
# 28528           缺失              缺失           584595            2.0
# 28529           12              12           817084            2.0
#
# [28530 rows x 1312 columns]

# %%
colummns_to_save = ['living_consump', 'deen_consump', 'durable', 'consump_durable', 'living_consump_durable', 'deen_consump_durable', 'year', 'resp1pid', 'fid20']

consump2020_merge = df_family_99[colummns_to_save]

merged_df = pd.merge(consump2020_merge, df_person, on='fid20', how='inner')

# %% [markdown]
# ## 个体层面的数据

# %%
import pandas as pd

# 创建一个示例 DataFrame
data = {
    'store': ['A', 'B', 'A', 'B', 'C', 'C', 'A', 'B'],
    'product': ['apple', 'banana', 'apple', 'banana', 'orange', 'orange', 'banana', 'apple'],
    'sales': [100, 200, 150, 300, 250, 300, 200, 400]
}

df = pd.DataFrame(data)

# 使用 groupby 按商店分组，并计算每个商店的总销售额
grouped_sales = df.groupby('store')['sales'].sum()

print(grouped_sales)
# Out:
# store
# A    450
# B    900
# C    550
# Name: sales, dtype: int64

# %%
import pandas as pd
import numpy as np

# 设置随机种子以确保结果可重复
np.random.seed(0)

# 生成模拟数据
n = 10  # 数据行数
df_person = pd.DataFrame({
    'fid20': np.random.randint(1, 10, size=n),  # 家庭ID，随机生成1到10之间的数字
    'pid': np.arange(n),  # 个人ID，从0到n-1
    'age': np.random.randint(10, 70, size=n),  # 年龄，随机生成10到70之间的数字
    'eduyear': np.random.randint(0, 20, size=n)  # 受教育年数，随机生成0到20之间的数字
})

# %%
print(df_person)
# Out:
#    fid20  pid  age  eduyear
# 0      6    0   16       17
# 1      1    1   34        5
# 2      4    2   34       13
# 3      4    3   22        8
# 4      8    4   68        9
# 5      4    5   11       19
# 6      6    6   48       16
# 7      3    7   49       19
# 8      5    8   33        5
# 9      8    9   56       15

# %%
# 应用上述代码，计算每个家庭的平均劳动力受教育程度并添加到新列average_eduyear
df_person = df_person[(df_person['age'] >= 16) & (df_person['age'] <= 65)]

print(df_person.groupby('fid20')['eduyear'].transform('mean'))

# 打印结果DataFrame的前几行
print("\n结果DataFrame：")
print(df_person)
# Out:
# 0    16.5
# 1     5.0
# 2    10.5
# 3    10.5
# 6    16.5
# 7    19.0
# 8     5.0
# 9    15.0
# Name: eduyear, dtype: float64
#
# 结果DataFrame：
#    fid20  pid  age  eduyear
# 0      6    0   16       17
# 1      1    1   34        5
# 2      4    2   34       13
# 3      4    3   22        8
# 6      6    6   48       16
# 7      3    7   49       19
# 8      5    8   33        5
# 9      8    9   56       15

# %%
# 读取Excel文件
import pandas as pd
df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")
# Out:
# C:\Users\gao_l\AppData\Local\Temp\ipykernel_31616\212442934.py:3: DtypeWarning: Columns (3,9,27,30,36,61,62,69,251,268,287,456,1097,1098,1099,1100,1101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_person = pd.read_csv("C:\\Users\\gao_l\\Desktop\\python\\10.dataanalyze1\\data\\table\\2020\\cfps2020person_202306.csv")

# %%
print(df_person)
# Out:
#               pid  code    fid20    fid18    fid16    fid14 fid12 fid10  \
# 0       100051501   501   100051   100051   100051   100051   不适用   不适用
# 1       100051502   502   100051   100051   100051   100051   不适用   不适用
# 2       100160601   601   100160   100160      不适用      不适用   不适用   不适用
# 3       100376551   551   100376   100376   100376      不适用   不适用   不适用
# 4       100551551   551   100551   100551   100551      不适用   不适用   不适用
# ...           ...   ...      ...      ...      ...      ...   ...   ...
# 28525  2350241551   551   235024   235024   235024      不适用   不适用   不适用
# 28526  2489151501   501  2489151  2489151  2489151  2489151   不适用   不适用
# 28527  2489151502   502  2489151  2489151  2489151  2489151   不适用   不适用
# 28528  2844271552   552  2844271  2844271  2844271      不适用   不适用   不适用
# 28529  6694541651   651  6694541      不适用      不适用      不适用   不适用   不适用
#
#        fid_base age  ... qz204 qz207  qz5 pg02  cfps2020edu  cfps2020sch  \
# 0        110043  51  ...   不适用     5    5  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 1        110043  54  ...   不适用     5    1  NaN  高中/中专/技校/职高  高中/中专/技校/职高
# 2        120009  31  ...   不适用     7    3  NaN         大学本科         大学本科
# 3        130094  23  ...   不适用     6    2  NaN           初中           初中
# 4        130281  30  ...   不适用     5    3  NaN         大学本科         大学本科
# ...         ...  ..  ...   ...   ...  ...  ...          ...          ...
# 28525    621081  61  ...   不适用     4    4  NaN           初中           缺失
# 28526    410954  48  ...   不适用     5    4  NaN           小学           缺失
# 28527    410954  47  ...   不适用     5    5  NaN       文盲/半文盲       文盲/半文盲
# 28528    420385  47  ...   NaN   NaN  NaN    否  高中/中专/技校/职高           缺失
# 28529    211229  24  ...   不适用     4    2  NaN  高中/中专/技校/职高  高中/中专/技校/职高
#
#       cfps2020eduy cfps2020eduy_im  interviewerid20 releaseversion
# 0               12              12           427784            2.0
# 1               12              12           427784            2.0
# 2               16              16           136496            2.0
# 3                9               9           856047            2.0
# 4               16              16           856047            2.0
# ...            ...             ...              ...            ...
# 28525           缺失              缺失           888818            2.0
# 28526           缺失              缺失           823876            2.0
# 28527            0               0           823876            2.0
# 28528           缺失              缺失           584595            2.0
# 28529           12              12           817084            2.0
#
# [28530 rows x 1312 columns]

# %%
# 数据清洗
df_person_0 = df_person[df_person["fid20"] == 100051]
print(df_person_0)
df_person = df_person[df_person['cfps2020eduy'] != "缺失"]

df_person['age'] = pd.to_numeric(df_person['age'], errors='coerce').astype('Int64')
df_person['cfps2020eduy'] = pd.to_numeric(df_person['cfps2020eduy'], errors='coerce').astype('Int64')

# cfps2020人口规模
df_person['familysize'] = df_person.groupby('fid20')['pid'].transform('count')
print(df_person['familysize'])

# cfps2020户主年龄
df_person['huage'] =  df_person['age']  

# cfps2020家庭劳动力平均受教育程度
# 筛选16-65岁的劳动力并计算每个家庭的平均受教育程度
df_person['eduyear_sum'] = df_person[(df_person['age'] >= 16) & (df_person['age'] <= 65)].groupby('fid20')['cfps2020eduy'].transform('sum')

# df_person['eduyear_sum'] = df_person.groupby('fid20')['eduyear_sum'].transform(
#     lambda x: x.fillna(x.dropna().iloc[0] if x.dropna().size > 0 else np.nan)
# )


df_person['eduyear_m'] = df_person['eduyear_sum']/df_person['familysize']

h_control = df_person[['age','cfps2020eduy','familysize', 'huage', 'eduyear_m', 'pid', 'fid20']]
# Out:
#           pid  code   fid20   fid18   fid16   fid14   fid12   fid10  fid_base  \
# 0   100051501   501  100051  100051  100051  100051     不适用     不适用    110043
# 1   100051502   502  100051  100051  100051  100051     不适用     不适用    110043
# 46  110043107   107  100051  100051  100051  100051  110043  110043    110043
#
#    age  ... qz204 qz207 qz5 pg02  cfps2020edu  cfps2020sch cfps2020eduy  \
# 0   51  ...   不适用     5   5  NaN  高中/中专/技校/职高  高中/中专/技校/职高           12
# 1   54  ...   不适用     5   1  NaN  高中/中专/技校/职高  高中/中专/技校/职高           12
# 46  26  ...   不适用     7   1  NaN           大专           大专           15
#
#    cfps2020eduy_im  interviewerid20 releaseversion
# 0               12           427784            2.0
# 1               12           427784            2.0
# 46              15           427784            2.0
#
# [3 rows x 1312 columns]
# 0        3
# 1        3
# 2        2
# 3        1
# 4        2
#         ..
# 28522    6
# 28523    6
# 28524    2
# 28527    2
# 28529    2
# Name: familysize, Length: 26156, dtype: int64

# %% [markdown]
# 参数 errors='coerce' 指定了当转换过程中遇到无法转换为数值的数据时应该采取的行为。
#
# 具体来说，errors 参数可以取以下几个值：
#
# ignore：如果传递的值无法转换为数字，则会忽略该值，返回原始数据。
# raise：如果传递的值无法转换为数字，则会抛出错误。
# coerce：如果传递的值无法转换为数字，则会将该值设置为 NaN（Not a Number，即“非数字”），这是一种特殊的浮点数值，用于表示缺失或无效的数据。

# %%
import pandas as pd
import numpy as np

# 模拟数据
data = {
    'fid20': [1, 1, 1, 2, 2, 3, 3, 3],
    'eduyear_sum': [np.nan, 10, np.nan, 20, np.nan, 30, np.nan, 30]
}
df = pd.DataFrame(data)

# 删除'eduyear_sum'列中的缺失值
df_cleaned = df.dropna(subset=['eduyear_sum'])

# 计算剩余值的总和
total_sum = df_cleaned['eduyear_sum'].sum()

print("清理后的DataFrame:")
print(df_cleaned)
print("\n'eduyear_sum'列的总和:", total_sum)
# Out:
# 清理后的DataFrame:
#    fid20  eduyear_sum
# 1      1         10.0
# 3      2         20.0
# 5      3         30.0
# 7      3         30.0
#
# 'eduyear_sum'列的总和: 90.0

# %%
print(df_family)
# Out:
#          fid20    fid18   fid16   fid14   fid12   fid10 provcd20  countyid20  \
# 0       100051   100051  100051  100051  110043  110043      北京市        45.0
# 1       100160   100160  100160  100160  120009  120009      天津市       189.0
# 2       100286   100286  100286  100286  130005  130005      河北省       239.0
# 3       100376   100376  100376  100376  130094  130094      河北省       235.0
# 4       100435   100435  100435  100435  130155  130155      河北省        52.0
# ...        ...      ...     ...     ...     ...     ...      ...         ...
# 11615  6694541  6694541  211229  211229  211229  211229   内蒙古自治区       592.0
# 11616  6704011  6704011  220306  220306  220306  220306      吉林省        59.0
# 11617  6759191  6759191  410650  410650  410650  410650      河南省       105.0
# 11618  6769401   620012  620012  620012  620012  620012      北京市       176.0
# 11619  6929111   450020  450020  450020  450020  450020      广东省       127.0
#
#           cid20 urban20  ... total_asset fswt_natcs20n fswtps_natcs20n  \
# 0      624942.0      城镇  ...    626000.0      0.760447        0.781139
# 1      800637.0      城镇  ...   1598700.0      1.136036        1.166948
# 2           NaN      缺失  ...      2500.0      1.752906        1.800603
# 3      418358.0      城镇  ...     10000.0      1.375133        1.412551
# 4      121200.0      乡村  ...    637000.0      0.871148        0.894852
# ...         ...     ...  ...         ...           ...             ...
# 11615       NaN      缺失  ...     75000.0      0.259222        0.161145
# 11616  123900.0      城镇  ...     59600.0      1.029976        1.058002
# 11617       NaN      城镇  ...    980000.0      0.692152        0.750392
# 11618  477349.0      城镇  ...      9000.0      0.155687        0.135495
# 11619       NaN      缺失  ...    290000.0      2.562173        2.631890
#
#        subsample  subpopulation familysize20  psu interviewerid20 interrupt  \
# 0              是        其它省市子总体            3   45          427784       NaN
# 1              是        其它省市子总体            3   79          136496       NaN
# 2              是        其它省市子总体            1   47          856047       NaN
# 3              是        其它省市子总体            3   47          856047       NaN
# 4              是        其它省市子总体            4   52          147691       NaN
# ...          ...            ...          ...  ...             ...       ...
# 11615          否         辽宁省子总体            3  171          817084       NaN
# 11616          是        其它省市子总体            3   59          283491       NaN
# 11617          是         河南省子总体            3  119          964048       NaN
# 11618          否         甘肃省子总体            1  152          300018       NaN
# 11619          是        其它省市子总体            1    4          717217       NaN
#
#       releaseversion
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 11615            1.0
# 11616            1.0
# 11617            1.0
# 11618            1.0
# 11619            1.0
#
# [11620 rows x 327 columns]

# %%
merged_data = pd.merge(consump2020, consump2022, on='fid20', how='inner')
print(merged_data)
# Out:
#       living_consump_x  deen_consump_x  durable_x  consump_durable_x  \
# 0                59160           32100      15000             121760
# 1                13500           36900       6500              51400
# 2                 9120           13620          0              38740
# 3               147340           19800     126000              43140
# 4                46060            4000      25000              25660
# ...                ...             ...        ...                ...
# 6921             22000           48400      17500              58200
# 6922             51600           41400       3000             110650
# 6923             13720            2260          0              16480
# 6924             31260           20590       5500             130850
# 6925             36640            6240        500              42380
#
#       living_consump_durable_x  deen_consump_durable_x  year_x  fid10_x  \
# 0                        59160                   17100    2020   110043
# 1                        13000                   30900    2020   130281
# 2                         9120                   13620    2020   130492
# 3                        27340                   13800    2020   130533
# 4                        21060                    4000    2020   130517
# ...                        ...                     ...     ...      ...
# 6921                     22000                   30900    2020   340346
# 6922                     49600                   40400    2020   211229
# 6923                     13720                    2260    2020   220306
# 6924                     31260                   15090    2020   410650
# 6925                     36440                    5940    2020   620012
#
#       fid12_x  fid14_x  ...  consump_durable_y  living_consump_durable_y  \
# 0      110043   100051  ...             112240                     72640
# 1      130281   100551  ...             128700                     25800
# 2      130492   100724  ...              39916                     11376
# 3      130533   100765  ...              51160                     19560
# 4      130517   130517  ...              19490                      9360
# ...       ...      ...  ...                ...                       ...
# 6921   340346   340346  ...              43000                     17000
# 6922   211229   211229  ...              45200                     22760
# 6923   220306   220306  ...              44412                     39000
# 6924   410650   410650  ...              52630                     26960
# 6925   620012   620012  ...              77640                     59240
#
#      deen_consump_durable_y  year_y   fid10_y   fid12_y   fid14_y   fid16_y  \
# 0                     26600    2022  110043.0  110043.0  100051.0  100051.0
# 1                     30900    2022  130281.0  130281.0  100551.0  100551.0
# 2                     14440    2022  130492.0  130492.0  100724.0  100724.0
# 3                     17900    2022  130533.0  130533.0  100765.0  100765.0
# 4                      9530    2022  130517.0  130517.0  130517.0  100782.0
# ...                     ...     ...       ...       ...       ...       ...
# 6921                  19000    2022  340346.0  340346.0  340346.0  284365.0
# 6922                   5440    2022  211229.0  211229.0  211229.0  211229.0
# 6923                   5312    2022  220306.0  220306.0  220306.0  220306.0
# 6924                  21670    2022  410650.0  410650.0  410650.0  410650.0
# 6925                  15400    2022  620012.0  620012.0  620012.0  620012.0
#
#         fid18_y      fid22
# 0      100051.0   100051.0
# 1      100551.0   100551.0
# 2      100724.0   100724.0
# 3      100765.0   100765.0
# 4      100782.0   100782.0
# ...         ...        ...
# 6921   284365.0  6662521.0
# 6922  6694541.0  6694541.0
# 6923  6704011.0  6704011.0
# 6924  6759191.0  6759191.0
# 6925   620012.0  6769401.0
#
# [6926 rows x 26 columns]

# %% [markdown]
# ## 数据转换
#
#
# <img src="figure/figure2.jpg" alt="示例图片" width="1200" height="350">

# %%
# 假设df_long是你的长格式DataFrame
data = {
    'pid': [1, 2, 1, 2],
    'year': [2000, 2000, 2020, 2020],
    'income': [10000, 25000, 50000, 100000]
}
df_long = pd.DataFrame(data)
print(df_long)

# 使用pivot函数转换为宽格式
df_wide = df_long.pivot(index=['pid'], columns='year', values='income')

# 重命名列
df_wide.columns = [f'income{col}' for col in df_wide.columns]

print(df_wide)
# Out:
#    pid  year  income
# 0    1  2000   10000
# 1    2  2000   25000
# 2    1  2020   50000
# 3    2  2020  100000
#      income2000  income2020
# pid
# 1         10000       50000
# 2         25000      100000

# %%
df_2022_combined_wide = df_2022_combined.pivot_table(index=['fid20'], columns='year', values='living_consump', aggfunc='mean')
print(df_2022_combined_wide)
# 重命名列

file_path = "C:\\Users\\gao_l\\Desktop\python\\10.dataanalyze1\\result\\df_2022_combined_wide.xlsx"
df_2022_combined_wide.to_excel(file_path, index=True)
# Out:
# year          2020      2022
# fid20
# 100051.0   59160.0  122640.0
# 100286.0   18400.0       NaN
# 100376.0   38800.0       NaN
# 100435.0   36450.0       NaN
# 100551.0   13500.0   26300.0
# ...            ...       ...
# 6694541.0  51600.0   22760.0
# 6704011.0  13720.0   39000.0
# 6759191.0  31260.0   26960.0
# 6769401.0  36640.0   59240.0
# 6929111.0  26610.0       NaN
#
# [12045 rows x 2 columns]
