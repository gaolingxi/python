# %% [markdown]
# # 第一章作业：Python程序设计基础
#
# > 课程：Python程序设计基础 | 授课教师：高泠溪
#
# ## 题目分布
#
# | 题型 | 题数 |
# |------|------|
# | 选择题 | 5 |
# | 填空题 | 5 |
# | 代码题 | 5 |
# | 代码纠错题 | 5 |
# | **合计** | **20** |
#
# > 提交方式：把代码cell填好，运行正确后提交 .ipynb 文件。

# %% [markdown]
# ## 一、选择题

# %% [markdown]
# ### 1. 下列哪个是Python的合法变量名？
#
# A. `1age`
# B. `my_age`
# C. `if`
# D. `my-age`

# %% [markdown]
# **答案：B**
# Python变量名必须以字母或下划线开头，不能以数字开头，不能用关键字（如if），不能含连字符。
#
# ---

# %% [markdown]
# ### 2. Python中 `=` 符号的作用是？
#
# A. 判断左右两边是否相等
# B. 把右边的值赋给左边的变量
# C. 引入外部模块
# D. 定义函数

# %% [markdown]
# **答案：B**
# `=` 是赋值运算符，方向从右到左。判断相等用 `==`。
#
# ---

# %% [markdown]
# ### 3. 下列哪个是正确的单行注释？
#
# A. `// 这是注释`
# B. `/* 这是注释 */`
# C. `# 这是注释`
# D. `-- 这是注释`

# %% [markdown]
# **答案：C**
# Python用 `#` 做单行注释。
#
# ---

# %% [markdown]
# ### 4. `input()` 函数的返回值类型是？
#
# A. int
# B. float
# C. str
# D. bool

# %% [markdown]
# **答案：C**
# input() 总是返回字符串，要当数字用得手动转 int() 或 float()。
#
# ---

# %% [markdown]
# ### 5. `print(10 * 6)` 的输出结果是？
#
# A. `10 * 6`
# B. `60`
# C. `106`
# D. 报错

# %% [markdown]
# **答案：B**
# print 先把表达式算出结果再打印。`10 * 6 = 60`。
#
# ---

# %% [markdown]
# ## 二、填空题

# %% [markdown]
# ### 1. Python中最常用的输出函数是 ________

# %% [markdown]
# **答案：** `print()`
#
# ---

# %% [markdown]
# ### 2. Python中用 ________ 符号做单行注释。

# %% [markdown]
# **答案：** `#`
#
# ---

# %% [markdown]
# ### 3. `print("Hello" + " World")` 的输出结果是 ________

# %% [markdown]
# **答案：** `Hello World`
#
# ---

# %% [markdown]
# ### 4. 在Python中，多行注释使用 ________ 包裹。

# %% [markdown]
# **答案：** 三引号（`'''` 或 `"""`）
#
# ---

# %% [markdown]
# ### 5. `age = input("你的年龄：")` 中输入25后，`age` 的值是 ________（写完整值含引号）。

# %% [markdown]
# **答案：** `'25'`（字符串，不是整数）
#
# ---

# %% [markdown]
# ## 三、代码题

# %% [markdown]
# ### 1. 基于命令行和Jupyter，使用input()和print()输入和输出你的学号。

# %%
# 请在下面填写代码：
student_id = input("请输入你的学号：")
print(student_id)

# %% [markdown]
# **答案：** 输入后原样输出学号，如输入 `202410312` 则输出 `202410312`
#
# ---

# %% [markdown]
# ### 2. 编写程序对《唐朝诡事录》进行评价。评分只能输入数字1~9，输出根据用户打分形成的星级评价，打几分就输出几个星（星星的Unicode编码是\u2605）。

# %%
# 请在下面填写代码：
score = int(input("请给《唐朝诡事录》打分（1~9）："))
print(score * "\u2605")

# %% [markdown]
# **答案：** 如输入5则输出 `★★★★★`
#
# ---

# %% [markdown]
# ### 3. 有如下表达式：`result = (4**2 + 45%2*4) / 5 < 456 // 3`。请用一段语句解释运算符优先级如何影响表达式的求值顺序，并用print输出result的值。

# %%
# 请在下面填写代码：
result = (4**2 + 45%2*4) / 5 < 456 // 3
print(result)

# %% [markdown]
# **答案：** `True`
# 解释：先算幂 `4**2=16`，再算取模 `45%2=1`，再算乘法 `1*4=4`，再加法 `16+4=20`，再除法 `20/5=4.0`，再算右边 `456//3=152`，最后比较 `4.0 < 152` 得 `True`。
#
# ---

# %% [markdown]
# ### 4. 从键盘输入两个整数，存放在变量a和b中，并交换a和b中的值，打印交换前后的结果。

# %%
# 请在下面填写代码：
a, b = int(input("a：")), int(input("b："))
a, b = b, a
print(a, b)

# %% [markdown]
# **答案：**
# ```
# 输入第一个整数：3
# 输入第二个整数：5
# 交换前：a = 3 , b = 5
# 交换后：a = 5 , b = 3
# ```
#
# ---

# %% [markdown]
# ### 5. 输入存款10000，存款期限5年和年利率3.4%，计算存款到期的利息和到期总额。（不使用课堂中没讲过的知识）

# %%
# 请在下面填写代码：
interest = 10000 * 0.034 * 5
print("利息：", interest)
print("总额：", 10000 + interest)

# %% [markdown]
# **答案：**
# ```
# 利息： 1700.0 元
# 到期总额： 11700.0 元
# ```
#
# ---

# %% [markdown]
# ### 6. 定义两个字符串变量 s1 = "Hello" 和 s2 = "World"，用 print 输出它们的拼接结果和各自长度。

# %%
# 请在下面填写代码：
print("Hello World")
print(len("Hello"), len("World"))

# %% [markdown]
# **答案：**
# ```
# Hello World
# 5 5
# ```
#
# ---

# %% [markdown]
# ## 四、代码纠错题

# %% [markdown]
# ### 1. 下面的代码运行后报错，请找出问题并改正
#
# ```python
# 1age = 25
# print(1age)
# ```

# %%
# 请在下面填写改正后的代码：
age = 25
print(age)

# %% [markdown]
# **改正说明：** 变量名不能以数字开头，`1age` 改成 `age`。
#
# ---

# %% [markdown]
# ### 2. 下面的代码运行后报错，请找出问题并改正
#
# ```python
# name = "小明";
# age = 20;
# print name
# ```

# %%
# 请在下面填写改正后的代码：
name = "小明"
age = 20
print(name)

# %% [markdown]
# **改正说明：** 两行错误：①Python不需要分号；②`print` 是函数必须加括号 `print(name)`。
#
# ---

# %% [markdown]
# ### 3. 下面的代码运行后报错，请找出问题并改正
#
# ```python
# if = 10
# print(if)
# ```

# %%
# 请在下面填写改正后的代码：
score = 10
print(score)

# %% [markdown]
# **改正说明：** `if` 是Python关键字，不能作为变量名。
#
# ---

# %% [markdown]
# ### 4. 下面的代码运行后报错，请找出问题并改正
#
# ```python
# age = input("你的年龄：")
# print(age + 1)
# ```

# %%
# 请在下面填写改正后的代码：
age = int(input("你的年龄："))
print(age + 1)

# %% [markdown]
# **改正说明：** `input()` 返回字符串，`"25" + 1` 会报错。用 `int()` 转成整数后再加。
#
# ---

# %% [markdown]
# ### 5. 下面的代码运行后报错，请找出问题并改正
#
# ```python
# x = 5
# 5 = x
# print(x)
# ```

# %%
# 请在下面填写改正后的代码：
x = 5
print(x)

# %% [markdown]
# **改正说明：** 赋值是"把右边的值放进左边的盒子"，数字5不能当盒子，删掉 `5 = x`。
#
# ---

# %% [markdown]
# ## 参考答案汇总
#
# ### 选择题
# 1. B  2. B  3. C  4. C  5. B
#
# ### 填空题
# 1. `print()`
# 2. `#`
# 3. `Hello World`
# 4. 三引号（`'''` 或 `"""`）
# 5. `'25'`
#
# ### 代码题
# 1. 输入输出学号
# 2. 输入1~9，输出对应数量的★
# 3. `True`
# 4. 交换两个整数
# 5. 利息1700.0元，总额11700.0元
# 6. `Hello World`，长度5和5
#
# ### 代码纠错题
# 1. 变量名不能以数字开头
# 2. 去掉分号，print加括号
# 3. `if`是关键字不能当变量名
# 4. `input()`返回字符串，用`int()`转换
# 5. 数字不能被赋值，删掉`5 = x`
